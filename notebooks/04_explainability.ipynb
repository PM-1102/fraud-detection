# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
import sys
sys.path.append('../src')
# SHAP values and explainability analysis
# from shap import TreeExplainer  # Uncomment when SHAP is installed

# %% [markdown]
# # Model Explainability - Fraud Detection
#
# Interpret and explain fraud detection model predictions.
# - Analyze feature importance scores
# - Generate SHAP (SHapley Additive exPlanations) explainability plots
# - Identify key fraud indicators
# - Provide business insights from model decisions
